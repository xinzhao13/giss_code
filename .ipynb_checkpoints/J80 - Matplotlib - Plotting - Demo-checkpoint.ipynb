# %% [markdown]
# # Workbook 8.0 - Plotting in Matplotlib

# %% [markdown]
# Use the following cell to import all the modules you need:

# %% [markdown]
# You may need this additional function to make plots display properly:

# %% [markdown]
# Let's import some data. This is the building data from earlier in the course:

# %%
df = pd.read_csv('building_data.csv')
df.sort_values(by='YEAR',inplace=True)
df.head()
# Out:
#     YEAR  STOREYS  HEIGHT_m
# 27  1907       57       741
# 24  1920       23       355
# 41  1924       18       340
# 17  1927       31       409
# 56  1930       34       476

# %% [markdown]
# We'll store the columns as X1, X2, X3 for ease of reference:

# %%
X1 = df['YEAR']
X2 = df['STOREYS']
X3 = df['HEIGHT_m']

# %% [markdown]
# Now, let's do some plotting:

# %% [markdown]
# We can also plot more than one set of data on the same plot:

# %% [markdown]
# Figures can be saved as image files:

# %% [markdown]
# The .scatter() function has a little more flexibility. Foe example, you can add a third and fourth dimension to your plot by altering the size and colour of your points:

# %%
# All colour maps can be found here:
# https://scipy.github.io/old-wiki/pages/Cookbook/Matplotlib/Show_colormaps

# %% [markdown]
# Let's import the coursework data:

# %%
cwdata = pd.read_csv('coursework_1_data_2017.csv')
X = cwdata['local_authority_area']
Y = cwdata['2008_pop'][:10]
cwdata.head()
# Out:
#            local_authority_area  2008_KSI  2009_KSI  2010_KSI  2008_pop  \
# 0          Barking and Dagenham        63        64        56    171500
# 1                        Barnet       136       128       127    338100
# 2                      Barnsley       112       116       100    225200
# 3  Bath and North East Somerset        34        20        20    177400
# 4                       Bedford        80        86        65    157100
#
#    2009_pop  2010_pop  Total_Budget  Cyclist_Safety  Child_Safety  \
# 0    175600    179500        139000           21000         22000
# 1    343100    347200        220000           50000         17000
# 2    226300    227000        160000           41000         45000
# 3    177700    177200        161000           33000         42000
# 4    158000    158200        130000           37000         52000
#
#    Motorcycle_Safety  Drink_Drive_Campaigns  Promote_Cycling  \
# 0              18000                  41000            18000
# ...

# %% [markdown]
# When you want to create a specific type of graph, you will probably have to look up the syntax in the online documentation: https://matplotlib.org/api/pyplot_api.html#module-matplotlib.pyplot.
#
# For example, let's work out how to do a bar chart:
